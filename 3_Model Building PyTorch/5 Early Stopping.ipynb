# %% [markdown]
# #<font color='blue' size='5px'/> Early Stopping<font/>

# %% [markdown]
# - **Purpose:** Early stopping involves monitoring the validation loss during training and stopping when it starts to increase, preventing overfitting.
#    - **Mathematics:** Early stopping is more of a strategy than a mathematical technique. It stops training when the validation loss exceeds a predefined threshold.
